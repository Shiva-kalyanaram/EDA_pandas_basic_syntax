# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Users\siva_\Downloads\pokemon_data.xlsx")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df[['Name', 'Type 1']]
# Out:
#                       Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %%
df.loc[df['Name']== 'Charmander']
# Out:
#    #        Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 4  4  Charmander   Fire    NaN  39      52       43       60       50     65
#
#    Generation  Legendary
# 4           1      False

# %%
df.iloc[0:2, 0:2]
# Out:
#    #       Name
# 0  1  Bulbasaur
# 1  2    Ivysaur

# %%
df.loc[df['Type 2']=='Dark'].sum()
# Out:
# #                                                          8277
# Name          GyaradosMega GyaradosTyranitarTyranitarMega Ty...
# Type 1        WaterRockRockGrassGrassWaterWaterWaterGrassWat...
# Type 2        DarkDarkDarkDarkDarkDarkDarkDarkDarkDarkDarkDa...
# HP                                                         1511
# Attack                                                     2196
# Defense                                                    1441
# Sp. Atk                                                    1636
# Sp. Def                                                    1397
# Speed                                                      1507
# Generation                                                   75
# Legendary                                                     1
# dtype: object

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Name', 'Attack'], ascending = True)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# # Making data changes

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Sp. Atk'] + df['Speed'] + df['Sp. Def']

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    269
# 1       80     60           1      False    342
# 2      100     80           1      False    442
# 3      120     80           1      False    502
# 4       50     65           1      False    266

# %%
df.shape
# Out:
# (800, 13)

# %%
# df = df.drop(columns = 'Total') dropping a column from dataframedf[]
# df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Adding a new column again using iloc

df['Total'] = df.iloc[:, 4:10].sum(axis = 1)
df.head()


df = df.drop(columns = 'Total')
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# # Filetring the data

# %%
df.loc[df['Type 1'] == 'Grass', (['Defense'])]
# Out:
#      Defense
# 0         49
# 1         63
# 2         83
# 3        123
# 48        55
# ..       ...
# 718       65
# 719       95
# 720      122
# 740       48
# 741       62
#
# [70 rows x 1 columns]

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['Speed'] > 30)]
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison  45      49       49       65
# 1      2                Ivysaur  Grass  Poison  60      62       63       80
# 2      3               Venusaur  Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 49    44                  Gloom  Grass  Poison  60      65       70       85
# 50    45              Vileplume  Grass  Poison  75      80       85      110
# 75    69             Bellsprout  Grass  Poison  50      75       35       70
# 76    70             Weepinbell  Grass  Poison  65      90       50       85
# 77    71             Victreebel  Grass  Poison  80     105       65      100
# 344  315                Roselia  Grass  Poison  50      60       45      100
# 451  406                  Budew  Grass  Poison  40      30       35       50
# ...

# %%
# to create New DF from existing df and convert into other file format using pandas

new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['Speed'] > 30)] 

new_df.to_csv('new_cond.csv')

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 4      4           Charmander     Fire     NaN   39      52       43       60
# 5      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %% [markdown]
# # Aggregate
#
# <!-- df.groupby(by=grouping_columns)[columns_to_show].function() -->

# %%
df.groupby('Type 1').mean().sort_values('Speed')
# Out:
# C:\Users\siva_\AppData\Local\Temp\ipykernel_54216\3811628006.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean().sort_values('Speed')
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# ...

# %%
df.groupby('Speed').sum().sort_values('Speed')
# Out:
# C:\Users\siva_\AppData\Local\Temp\ipykernel_54216\2432029669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Speed').sum().sort_values('Speed')
#           #   HP  Attack  Defense  Sp. Atk  Sp. Def  Generation  Legendary
# Speed
# 5       659  155      95      270       50      315           6          0
# 10     1363  139     230      231       79      176          12          0
# 15     2472  559     430      483      315      305          25          0
# 20     5075  859     980     1135      909      931          48          0
# 22      564   54      78      103       53       45           5          0
# ...     ...  ...     ...      ...      ...      ...         ...        ...
# 140     251  166     200      140      274      200           2          1
# ...

# %%
df.groupby('Generation')['Defense', 'Speed'].sum()
# Out:
# C:\Users\siva_\AppData\Local\Temp\ipykernel_54216\4060261142.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Generation')['Defense', 'Speed'].sum()
#             Defense  Speed
# Generation
# 1             11763  12049
# 2              7779   6552
# 3             11856  10708
# 4              9454   8632
# 5             11934  11233
# 6              6288   5448

# %%
df.groupby('Generation')['Type 1', 'Type 2'].count()
# Out:
# C:\Users\siva_\AppData\Local\Temp\ipykernel_54216\2875191624.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Generation')['Type 1', 'Type 2'].count()
#             Type 1  Type 2
# Generation
# 1              166      78
# 2              106      55
# 3              160      82
# 4              121      67
# 5              165      82
# 6               82      50

# %% [markdown]
# # concatenation data

# %%
results = df.groupby('Generation')['Type 1'].count()

# %%
new_df = pd.concat([new_df, results])
new_df.head()
# Out:
#        #                   Name Type 1  Type 2    HP  Attack  Defense  \
# 0    1.0              Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1    2.0                Ivysaur  Grass  Poison  60.0    62.0     63.0
# 2    3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 3    3.0  VenusaurMega Venusaur  Grass  Poison  80.0   100.0    123.0
# 49  44.0                  Gloom  Grass  Poison  60.0    65.0     70.0
#
#     Sp. Atk  Sp. Def  Speed  Generation Legendary   0
# 0      65.0     65.0   45.0         1.0     False NaN
# 1      80.0     80.0   60.0         1.0     False NaN
# 2     100.0    100.0   80.0         1.0     False NaN
# 3     122.0    120.0   80.0         1.0     False NaN
# 49     85.0     75.0   40.0         1.0     False NaN

# %%
new_df.reset_index()
# Out:
#     index      #                   Name Type 1  Type 2    HP  Attack  Defense  \
# 0       0    1.0              Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1       1    2.0                Ivysaur  Grass  Poison  60.0    62.0     63.0
# 2       2    3.0               Venusaur  Grass  Poison  80.0    82.0     83.0
# 3       3    3.0  VenusaurMega Venusaur  Grass  Poison  80.0   100.0    123.0
# 4      49   44.0                  Gloom  Grass  Poison  60.0    65.0     70.0
# 5      50   45.0              Vileplume  Grass  Poison  75.0    80.0     85.0
# 6      75   69.0             Bellsprout  Grass  Poison  50.0    75.0     35.0
# 7      76   70.0             Weepinbell  Grass  Poison  65.0    90.0     50.0
# 8      77   71.0             Victreebel  Grass  Poison  80.0   105.0     65.0
# 9     344  315.0                Roselia  Grass  Poison  50.0    60.0     45.0
# 10    451  406.0                  Budew  Grass  Poison  40.0    30.0     35.0
# ...
